# %%
# Same DataSet Metrics changed to 0.1(Random forest)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.naive_bayes import MultinomialNB
naive_bayes = MultinomialNB()
naive_bayes.fit(x_train_tfidf, y_train)

# Predictions
y_pred = naive_bayes.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_1 = accuracy_score(y_test, y_pred)
precision_1 = precision_score(y_test, y_pred, average='weighted')
recall_1 = recall_score(y_test, y_pred, average='weighted')
f1_1 = f1_score(y_test, y_pred, average='weighted')
conf_matrix_1 = confusion_matrix(y_test, y_pred)

# Print metrics
print(f'Accuracy: {accuracy_1}')
print(f'Precision: {precision_1}')
print(f'Recall: {recall_1}')
print(f'F1 Score: {f1_1}')
print(f'Confusion Matrix:\n{conf_matrix_1}')
# Out:
# (36000,) (4000,) (36000,) (4000,)
# Accuracy: 0.8525
# Precision: 0.8525147126324136
# Recall: 0.8525
# F1 Score: 0.8525020281863526
# Confusion Matrix:
# [[1694  290]
#  [ 300 1716]]

# %%
# Same DataSet Metrics changed to 0.15(Random forest)

import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.15,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.naive_bayes import MultinomialNB
naive_bayes = MultinomialNB()
naive_bayes.fit(x_train_tfidf, y_train)

# Predictions
y_pred = naive_bayes.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_15 = accuracy_score(y_test, y_pred)
precision_15 = precision_score(y_test, y_pred, average='weighted')
recall_15 = recall_score(y_test, y_pred, average='weighted')
f1_15 = f1_score(y_test, y_pred, average='weighted')
conf_matrix_15 = confusion_matrix(y_test, y_pred)

# Print metrics
print(f'Accuracy: {accuracy_15}')
print(f'Precision: {precision_15}')
print(f'Recall: {recall_15}')
print(f'F1 Score: {f1_15}')
print(f'Confusion Matrix:\n{conf_matrix_15}')
# Out:
# (34000,) (6000,) (34000,) (6000,)
# Accuracy: 0.8508333333333333
# Precision: 0.8508496706499633
# Recall: 0.8508333333333333
# F1 Score: 0.8508346717032358
# Confusion Matrix:
# [[2543  439]
#  [ 456 2562]]

# %%
# Same DataSet Metrics changed to 0.2(Random forest)

import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.naive_bayes import MultinomialNB
naive_bayes = MultinomialNB()
naive_bayes.fit(x_train_tfidf, y_train)

# Predictions
y_pred = naive_bayes.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_2 = accuracy_score(y_test, y_pred)
precision_2 = precision_score(y_test, y_pred, average='weighted')
recall_2 = recall_score(y_test, y_pred, average='weighted')
f1_2 = f1_score(y_test, y_pred, average='weighted')
conf_matrix_2 = confusion_matrix(y_test, y_pred)

# Print metrics
print(f'Accuracy: {accuracy_2}')
print(f'Precision: {precision_2}')
print(f'Recall: {recall_2}')
print(f'F1 Score: {f1_2}')
print(f'Confusion Matrix:\n{conf_matrix_2}')
# Out:
# (32000,) (8000,) (32000,) (8000,)
# Accuracy: 0.851625
# Precision: 0.851638924375499
# Recall: 0.851625
# F1 Score: 0.8516271584735546
# Confusion Matrix:
# [[3382  584]
#  [ 603 3431]]

# %%
# Same DataSet Metrics changed to 0.25(naïve bayes)

import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.naive_bayes import MultinomialNB
naive_bayes = MultinomialNB()
naive_bayes.fit(x_train_tfidf, y_train)

# Predictions
y_pred = naive_bayes.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_25 = accuracy_score(y_test, y_pred)
precision_25 = precision_score(y_test, y_pred, average='weighted')
recall_25 = recall_score(y_test, y_pred, average='weighted')
f1_25 = f1_score(y_test, y_pred, average='weighted')
conf_matrix_25 = confusion_matrix(y_test, y_pred)

# Print metrics
print(f'Accuracy: {accuracy_25}')
print(f'Precision: {precision_25}')
print(f'Recall: {recall_25}')
print(f'F1 Score: {f1_25}')
print(f'Confusion Matrix:\n{conf_matrix_25}')
# Out:
# (30000,) (10000,) (30000,) (10000,)
# Accuracy: 0.8519
# Precision: 0.8519284759684761
# Recall: 0.8519
# F1 Score: 0.8519025755158931
# Confusion Matrix:
# [[4236  722]
#  [ 759 4283]]

# %%
#SVM Method NOW

# %%
#SAME DATASET ,METHOD CHANGED TO SVM ,CHANGES IN TEST SIZE 
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.svm import SVC

# Train the SVM classifier
svm_classifier = SVC()
svm_classifier.fit(x_train_tfidf, y_train)

# Predictions
y_pred_svm = svm_classifier.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_svm_2 = accuracy_score(y_test, y_pred_svm)
precision_svm_2 = precision_score(y_test, y_pred_svm, average='weighted')
recall_svm_2 = recall_score(y_test, y_pred_svm, average='weighted')
f1_svm_2 = f1_score(y_test, y_pred_svm, average='weighted')
conf_matrix_svm_2 = confusion_matrix(y_test, y_pred_svm)

# Print metrics
print(f'Accuracy (SVM): {accuracy_svm_2}')
print(f'Precision (SVM): {precision_svm_2}')
print(f'Recall (SVM): {recall_svm_2}')
print(f'F1 Score (SVM): {f1_svm_2}')
print(f'Confusion Matrix (SVM):\n{conf_matrix_svm_2}')
# Out:
# (32000,) (8000,) (32000,) (8000,)
# Accuracy (SVM): 0.895625
# Precision (SVM): 0.8956980266238919
# Recall (SVM): 0.895625
# F1 Score (SVM): 0.8956127768902885
# Confusion Matrix (SVM):
# [[3519  447]
#  [ 388 3646]]

# %%
#SAME DATASET ,METHOD CHANGED TO SVM ,CHANGES IN TEST SIZE 
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.15,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.svm import SVC

# Train the SVM classifier
svm_classifier = SVC()
svm_classifier.fit(x_train_tfidf, y_train)

# Predictions
y_pred_svm = svm_classifier.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_svm_15 = accuracy_score(y_test, y_pred_svm)
precision_svm_15 = precision_score(y_test, y_pred_svm, average='weighted')
recall_svm_15 = recall_score(y_test, y_pred_svm, average='weighted')
f1_svm_15 = f1_score(y_test, y_pred_svm, average='weighted')
conf_matrix_svm_15 = confusion_matrix(y_test, y_pred_svm)

# Print metrics
print(f'Accuracy (SVM): {accuracy_svm_15}')
print(f'Precision (SVM): {precision_svm_15}')
print(f'Recall (SVM): {recall_svm_15}')
print(f'F1 Score (SVM): {f1_svm_15}')
print(f'Confusion Matrix (SVM):\n{conf_matrix_svm_15}')
# Out:
# (34000,) (6000,) (34000,) (6000,)
# Accuracy (SVM): 0.898
# Precision (SVM): 0.8980626189611318
# Recall (SVM): 0.898
# F1 Score (SVM): 0.8979913852844835
# Confusion Matrix (SVM):
# [[2656  326]
#  [ 286 2732]]

# %%
#SAME DATASET ,METHOD CHANGED TO SVM ,CHANGES IN TEST SIZE 
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.svm import SVC

# Train the SVM classifier
svm_classifier = SVC()
svm_classifier.fit(x_train_tfidf, y_train)

# Predictions
y_pred_svm = svm_classifier.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_svm_1 = accuracy_score(y_test, y_pred_svm)
precision_svm_1 = precision_score(y_test, y_pred_svm, average='weighted')
recall_svm_1 = recall_score(y_test, y_pred_svm, average='weighted')
f1_svm_1 = f1_score(y_test, y_pred_svm, average='weighted')
conf_matrix_svm_1 = confusion_matrix(y_test, y_pred_svm)

# Print metrics
print(f'Accuracy (SVM): {accuracy_svm_1}')
print(f'Precision (SVM): {precision_svm_1}')
print(f'Recall (SVM): {recall_svm_1}')
print(f'F1 Score (SVM): {f1_svm_1}')
print(f'Confusion Matrix (SVM):\n{conf_matrix_svm_1}')
# Out:
# (36000,) (4000,) (36000,) (4000,)
# Accuracy (SVM): 0.90275
# Precision (SVM): 0.9027862465928964
# Recall (SVM): 0.90275
# F1 Score (SVM): 0.9027432338589945
# Confusion Matrix (SVM):
# [[1779  205]
#  [ 184 1832]]

# %%
#SAME DATASET ,METHOD CHANGED TO SVM ,CHANGES IN TEST SIZE 
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.svm import SVC

# Train the SVM classifier
svm_classifier = SVC()
svm_classifier.fit(x_train_tfidf, y_train)

# Predictions
y_pred_svm = svm_classifier.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_svm_25 = accuracy_score(y_test, y_pred_svm)
precision_svm_25 = precision_score(y_test, y_pred_svm, average='weighted')
recall_svm_25 = recall_score(y_test, y_pred_svm, average='weighted')
f1_svm_25 = f1_score(y_test, y_pred_svm, average='weighted')
conf_matrix_svm_25 = confusion_matrix(y_test, y_pred_svm)

# Print metrics
print(f'Accuracy (SVM): {accuracy_svm_25}')
print(f'Precision (SVM): {precision_svm_25}')
print(f'Recall (SVM): {recall_svm_25}')
print(f'F1 Score (SVM): {f1_svm_25}')
print(f'Confusion Matrix (SVM):\n{conf_matrix_svm_25}')
# Out:
# (30000,) (10000,) (30000,) (10000,)
# Accuracy (SVM): 0.8934
# Precision (SVM): 0.8934864348198344
# Recall (SVM): 0.8934
# F1 Score (SVM): 0.8933860103173349
# Confusion Matrix (SVM):
# [[4385  573]
#  [ 493 4549]]

# %%
#DECISION TREE

# %%
#SAME DATASET METHOD CHANGED TO DECISION TREE (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.tree import DecisionTreeClassifier

# Train the Decision Tree classifier
decision_tree = DecisionTreeClassifier()
decision_tree.fit(x_train_tfidf, y_train)

# Predictions
y_pred_dt = decision_tree.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_dt_1 = accuracy_score(y_test, y_pred_dt)
precision_dt_1 = precision_score(y_test, y_pred_dt, average='weighted')
recall_dt_1 = recall_score(y_test, y_pred_dt, average='weighted')
f1_dt_1 = f1_score(y_test, y_pred_dt, average='weighted')
conf_matrix_dt_1 = confusion_matrix(y_test, y_pred_dt)

# Print metrics
print(f'Accuracy (Decision Tree): {accuracy_dt_1}')
print(f'Precision (Decision Tree): {precision_dt_1}')
print(f'Recall (Decision Tree): {recall_dt_1}')
print(f'F1 Score (Decision Tree): {f1_dt_1}')
print(f'Confusion Matrix (Decision Tree):\n{conf_matrix_dt_1}')
# Out:
# (36000,) (4000,) (36000,) (4000,)
# Accuracy (Decision Tree): 0.71375
# Precision (Decision Tree): 0.7138459853724433
# Recall (Decision Tree): 0.71375
# F1 Score (Decision Tree): 0.7137494096093381
# Confusion Matrix (Decision Tree):
# [[1428  556]
#  [ 589 1427]]

# %%
#SAME DATASET METHOD CHANGED TO DECISION TREE (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.tree import DecisionTreeClassifier

# Train the Decision Tree classifier
decision_tree = DecisionTreeClassifier()
decision_tree.fit(x_train_tfidf, y_train)

# Predictions
y_pred_dt = decision_tree.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_dt_25 = accuracy_score(y_test, y_pred_dt)
precision_dt_25 = precision_score(y_test, y_pred_dt, average='weighted')
recall_dt_25 = recall_score(y_test, y_pred_dt, average='weighted')
f1_dt_25 = f1_score(y_test, y_pred_dt, average='weighted')
conf_matrix_dt_25 = confusion_matrix(y_test, y_pred_dt)

# Print metrics
print(f'Accuracy (Decision Tree): {accuracy_dt_25}')
print(f'Precision (Decision Tree): {precision_dt_25}')
print(f'Recall (Decision Tree): {recall_dt_25}')
print(f'F1 Score (Decision Tree): {f1_dt_25}')
print(f'Confusion Matrix (Decision Tree):\n{conf_matrix_dt_25}')
# Out:
# (30000,) (10000,) (30000,) (10000,)
# Accuracy (Decision Tree): 0.7106
# Precision (Decision Tree): 0.7106133363217213
# Recall (Decision Tree): 0.7106
# F1 Score (Decision Tree): 0.7105634218164214
# Confusion Matrix (Decision Tree):
# [[3472 1486]
#  [1408 3634]]

# %%
#SAME DATASET METHOD CHANGED TO DECISION TREE (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.15,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.tree import DecisionTreeClassifier

# Train the Decision Tree classifier
decision_tree = DecisionTreeClassifier()
decision_tree.fit(x_train_tfidf, y_train)

# Predictions
y_pred_dt = decision_tree.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_dt_15 = accuracy_score(y_test, y_pred_dt)
precision_dt_15 = precision_score(y_test, y_pred_dt, average='weighted')
recall_dt_15 = recall_score(y_test, y_pred_dt, average='weighted')
f1_dt_15 = f1_score(y_test, y_pred_dt, average='weighted')
conf_matrix_dt_15 = confusion_matrix(y_test, y_pred_dt)

# Print metrics
print(f'Accuracy (Decision Tree): {accuracy_dt_15}')
print(f'Precision (Decision Tree): {precision_dt_15}')
print(f'Recall (Decision Tree): {recall_dt_15}')
print(f'F1 Score (Decision Tree): {f1_dt_15}')
print(f'Confusion Matrix (Decision Tree):\n{conf_matrix_dt_15}')
# Out:
# (34000,) (6000,) (34000,) (6000,)
# Accuracy (Decision Tree): 0.712
# Precision (Decision Tree): 0.7120468155538647
# Recall (Decision Tree): 0.712
# F1 Score (Decision Tree): 0.7120005440000605
# Confusion Matrix (Decision Tree):
# [[2135  847]
#  [ 881 2137]]

# %%
#SAME DATASET METHOD CHANGED TO DECISION TREE (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.tree import DecisionTreeClassifier

# Train the Decision Tree classifier
decision_tree = DecisionTreeClassifier()
decision_tree.fit(x_train_tfidf, y_train)

# Predictions
y_pred_dt = decision_tree.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_dt_2 = accuracy_score(y_test, y_pred_dt)
precision_dt_2 = precision_score(y_test, y_pred_dt, average='weighted')
recall_dt_2 = recall_score(y_test, y_pred_dt, average='weighted')
f1_dt_2 = f1_score(y_test, y_pred_dt, average='weighted')
conf_matrix_dt_2 = confusion_matrix(y_test, y_pred_dt)

# Print metrics
print(f'Accuracy (Decision Tree): {accuracy_dt_2}')
print(f'Precision (Decision Tree): {precision_dt_2}')
print(f'Recall (Decision Tree): {recall_dt_2}')
print(f'F1 Score (Decision Tree): {f1_dt_2}')
print(f'Confusion Matrix (Decision Tree):\n{conf_matrix_dt_2}')
# Out:
# (32000,) (8000,) (32000,) (8000,)
# Accuracy (Decision Tree): 0.704
# Precision (Decision Tree): 0.704154116087657
# Recall (Decision Tree): 0.704
# F1 Score (Decision Tree): 0.7039918599491247
# Confusion Matrix (Decision Tree):
# [[2826 1140]
#  [1228 2806]]

# %%
#RANDOM FOREST

# %%
#SAME DATASET METHOD CHANGED TO RANDOM FOREST (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.ensemble import RandomForestClassifier

# Train the Random Forest classifier
random_forest = RandomForestClassifier(n_estimators=100, random_state=42)
random_forest.fit(x_train_tfidf, y_train)

# Predictions
y_pred_rf = random_forest.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_rf_1 = accuracy_score(y_test, y_pred_rf)
precision_rf_1 = precision_score(y_test, y_pred_rf, average='weighted')
recall_rf_1 = recall_score(y_test, y_pred_rf, average='weighted')
f1_rf_1 = f1_score(y_test, y_pred_rf, average='weighted')
conf_matrix_rf_1 = confusion_matrix(y_test, y_pred_rf)

# Print metrics
print(f'Accuracy (Random Forest): {accuracy_rf_1}')
print(f'Precision (Random Forest): {precision_rf_1}')
print(f'Recall (Random Forest): {recall_rf_1}')
print(f'F1 Score (Random Forest): {f1_rf_1}')
print(f'Confusion Matrix (Random Forest):\n{conf_matrix_rf_1}')
# Out:
# (36000,) (4000,) (36000,) (4000,)
# Accuracy (Random Forest): 0.84375
# Precision (Random Forest): 0.8439692636155837
# Recall (Random Forest): 0.84375
# F1 Score (Random Forest): 0.8437431151375566
# Confusion Matrix (Random Forest):
# [[1695  289]
#  [ 336 1680]]

# %%
#SAME DATASET METHOD CHANGED TO RANDOM FOREST (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.15,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.ensemble import RandomForestClassifier

# Train the Random Forest classifier
random_forest = RandomForestClassifier(n_estimators=100, random_state=42)
random_forest.fit(x_train_tfidf, y_train)

# Predictions
y_pred_rf = random_forest.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_rf_15 = accuracy_score(y_test, y_pred_rf)
precision_rf_15 = precision_score(y_test, y_pred_rf, average='weighted')
recall_rf_15 = recall_score(y_test, y_pred_rf, average='weighted')
f1_rf_15 = f1_score(y_test, y_pred_rf, average='weighted')
conf_matrix_rf_15 = confusion_matrix(y_test, y_pred_rf)

# Print metrics
print(f'Accuracy (Random Forest): {accuracy_rf_15}')
print(f'Precision (Random Forest): {precision_rf_15}')
print(f'Recall (Random Forest): {recall_rf_15}')
print(f'F1 Score (Random Forest): {f1_rf_15}')
print(f'Confusion Matrix (Random Forest):\n{conf_matrix_rf_15}')
# Out:
# (34000,) (6000,) (34000,) (6000,)
# Accuracy (Random Forest): 0.8446666666666667
# Precision (Random Forest): 0.844963124819079
# Recall (Random Forest): 0.8446666666666667
# F1 Score (Random Forest): 0.8446492682198329
# Confusion Matrix (Random Forest):
# [[2558  424]
#  [ 508 2510]]

# %%
#SAME DATASET METHOD CHANGED TO RANDOM FOREST (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.ensemble import RandomForestClassifier

# Train the Random Forest classifier
random_forest = RandomForestClassifier(n_estimators=100, random_state=42)
random_forest.fit(x_train_tfidf, y_train)

# Predictions
y_pred_rf = random_forest.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_rf_2 = accuracy_score(y_test, y_pred_rf)
precision_rf_2 = precision_score(y_test, y_pred_rf, average='weighted')
recall_rf_2 = recall_score(y_test, y_pred_rf, average='weighted')
f1_rf_2 = f1_score(y_test, y_pred_rf, average='weighted')
conf_matrix_rf_2 = confusion_matrix(y_test, y_pred_rf)

# Print metrics
print(f'Accuracy (Random Forest): {accuracy_rf_2}')
print(f'Precision (Random Forest): {precision_rf_2}')
print(f'Recall (Random Forest): {recall_rf_2}')
print(f'F1 Score (Random Forest): {f1_rf_2}')
print(f'Confusion Matrix (Random Forest):\n{conf_matrix_rf_2}')
# Out:
# (32000,) (8000,) (32000,) (8000,)
# Accuracy (Random Forest): 0.84575
# Precision (Random Forest): 0.8459989396488193
# Recall (Random Forest): 0.84575
# F1 Score (Random Forest): 0.845742287376598
# Confusion Matrix (Random Forest):
# [[3399  567]
#  [ 667 3367]]

# %%
#SAME DATASET METHOD CHANGED TO RANDOM FOREST (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.ensemble import RandomForestClassifier

# Train the Random Forest classifier
random_forest = RandomForestClassifier(n_estimators=100, random_state=42)
random_forest.fit(x_train_tfidf, y_train)

# Predictions
y_pred_rf = random_forest.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_rf_25 = accuracy_score(y_test, y_pred_rf)
precision_rf_25 = precision_score(y_test, y_pred_rf, average='weighted')
recall_rf_25 = recall_score(y_test, y_pred_rf, average='weighted')
f1_rf_25 = f1_score(y_test, y_pred_rf, average='weighted')
conf_matrix_rf_25 = confusion_matrix(y_test, y_pred_rf)

# Print metrics
print(f'Accuracy (Random Forest): {accuracy_rf_25}')
print(f'Precision (Random Forest): {precision_rf_25}')
print(f'Recall (Random Forest): {recall_rf_25}')
print(f'F1 Score (Random Forest): {f1_rf_25}')
print(f'Confusion Matrix (Random Forest):\n{conf_matrix_rf_25}')
# Out:
# (30000,) (10000,) (30000,) (10000,)
# Accuracy (Random Forest): 0.8459
# Precision (Random Forest): 0.8461872103432905
# Recall (Random Forest): 0.8459
# F1 Score (Random Forest): 0.8458893899390325
# Confusion Matrix (Random Forest):
# [[4255  703]
#  [ 838 4204]]

# %%
#KNN

# %%
#SAME DATASET METHOD CHANGED TO KNN (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.neighbors import KNeighborsClassifier

# Train the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train_tfidf, y_train)

# Predictions
y_pred_knn = knn.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_knn_1 = accuracy_score(y_test, y_pred_knn)
precision_knn_1 = precision_score(y_test, y_pred_knn, average='weighted')
recall_knn_1 = recall_score(y_test, y_pred_knn, average='weighted')
f1_knn_1 = f1_score(y_test, y_pred_knn, average='weighted')
conf_matrix_knn_1 = confusion_matrix(y_test, y_pred_knn)

# Print metrics
print(f'Accuracy (KNN): {accuracy_knn_1}')
print(f'Precision (KNN): {precision_knn_1}')
print(f'Recall (KNN): {recall_knn_1}')
print(f'F1 Score (KNN): {f1_knn_1}')
print(f'Confusion Matrix (KNN):\n{conf_matrix_knn_1}')
# Out:
# (36000,) (4000,) (36000,) (4000,)
# Accuracy (KNN): 0.7325
# Precision (KNN): 0.7340109809744481
# Recall (KNN): 0.7325
# F1 Score (KNN): 0.7319244102271818
# Confusion Matrix (KNN):
# [[1364  620]
#  [ 450 1566]]

# %%
#SAME DATASET METHOD CHANGED TO KNN (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.15,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.neighbors import KNeighborsClassifier

# Train the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train_tfidf, y_train)

# Predictions
y_pred_knn = knn.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_knn_15 = accuracy_score(y_test, y_pred_knn)
precision_knn_15 = precision_score(y_test, y_pred_knn, average='weighted')
recall_knn_15 = recall_score(y_test, y_pred_knn, average='weighted')
f1_knn_15 = f1_score(y_test, y_pred_knn, average='weighted')
conf_matrix_knn_15 = confusion_matrix(y_test, y_pred_knn)

# Print metrics
print(f'Accuracy (KNN): {accuracy_knn_15}')
print(f'Precision (KNN): {precision_knn_15}')
print(f'Recall (KNN): {recall_knn_15}')
print(f'F1 Score (KNN): {f1_knn_15}')
print(f'Confusion Matrix (KNN):\n{conf_matrix_knn_15}')
# Out:
# (34000,) (6000,) (34000,) (6000,)
# Accuracy (KNN): 0.7196666666666667
# Precision (KNN): 0.721549228843555
# Recall (KNN): 0.7196666666666667
# F1 Score (KNN): 0.7189379176344889
# Confusion Matrix (KNN):
# [[1997  985]
#  [ 697 2321]]

# %%
#SAME DATASET METHOD CHANGED TO KNN (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.neighbors import KNeighborsClassifier

# Train the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train_tfidf, y_train)

# Predictions
y_pred_knn = knn.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_knn_2 = accuracy_score(y_test, y_pred_knn)
precision_knn_2 = precision_score(y_test, y_pred_knn, average='weighted')
recall_knn_2 = recall_score(y_test, y_pred_knn, average='weighted')
f1_knn_2 = f1_score(y_test, y_pred_knn, average='weighted')
conf_matrix_knn_2 = confusion_matrix(y_test, y_pred_knn)

# Print metrics
print(f'Accuracy (KNN): {accuracy_knn_2}')
print(f'Precision (KNN): {precision_knn_2}')
print(f'Recall (KNN): {recall_knn_2}')
print(f'F1 Score (KNN): {f1_knn_2}')
print(f'Confusion Matrix (KNN):\n{conf_matrix_knn_2}')
# Out:
# (32000,) (8000,) (32000,) (8000,)
# Accuracy (KNN): 0.726625
# Precision (KNN): 0.72777368121682
# Recall (KNN): 0.726625
# F1 Score (KNN): 0.7261379958864013
# Confusion Matrix (KNN):
# [[2720 1246]
#  [ 941 3093]]

# %%
#SAME DATASET METHOD CHANGED TO KNN (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

from sklearn.neighbors import KNeighborsClassifier

# Train the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train_tfidf, y_train)

# Predictions
y_pred_knn = knn.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_knn_25 = accuracy_score(y_test, y_pred_knn)
precision_knn_25 = precision_score(y_test, y_pred_knn, average='weighted')
recall_knn_25 = recall_score(y_test, y_pred_knn, average='weighted')
f1_knn_25 = f1_score(y_test, y_pred_knn, average='weighted')
conf_matrix_knn_25 = confusion_matrix(y_test, y_pred_knn)

# Print metrics
print(f'Accuracy (KNN): {accuracy_knn_25}')
print(f'Precision (KNN): {precision_knn_25}')
print(f'Recall (KNN): {recall_knn_25}')
print(f'F1 Score (KNN): {f1_knn_25}')
print(f'Confusion Matrix (KNN):\n{conf_matrix_knn_25}')
# Out:
# (30000,) (10000,) (30000,) (10000,)
# Accuracy (KNN): 0.7242
# Precision (KNN): 0.7250282965998671
# Recall (KNN): 0.7242
# F1 Score (KNN): 0.7238225551145642
# Confusion Matrix (KNN):
# [[3414 1544]
#  [1214 3828]]

# %%
#LOGISTIC REGRESSION

# %%
#SAME DATASET METHOD CHANGED TO KNN (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)
from sklearn.linear_model import LogisticRegression

# Train the Logistic Regression classifier
logistic_regression = LogisticRegression(max_iter=1000)
logistic_regression.fit(x_train_tfidf, y_train)

# Predictions
y_pred_lr = logistic_regression.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_lr_1 = accuracy_score(y_test, y_pred_lr)
precision_lr_1 = precision_score(y_test, y_pred_lr, average='weighted')
recall_lr_1 = recall_score(y_test, y_pred_lr, average='weighted')
f1_lr_1 = f1_score(y_test, y_pred_lr, average='weighted')
conf_matrix_lr_1 = confusion_matrix(y_test, y_pred_lr)

# Print metrics
print(f'Accuracy (Logistic Regression): {accuracy_lr_1}')
print(f'Precision (Logistic Regression): {precision_lr_1}')
print(f'Recall (Logistic Regression): {recall_lr_1}')
print(f'F1 Score (Logistic Regression): {f1_lr_1}')
print(f'Confusion Matrix (Logistic Regression):\n{conf_matrix_lr_1}')
# Out:
# (36000,) (4000,) (36000,) (4000,)
# Accuracy (Logistic Regression): 0.89675
# Precision (Logistic Regression): 0.8968111849702525
# Recall (Logistic Regression): 0.89675
# F1 Score (Logistic Regression): 0.8967397179348832
# Confusion Matrix (Logistic Regression):
# [[1764  220]
#  [ 193 1823]]

# %%
#SAME DATASET METHOD CHANGED TO KNN (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.15,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)
from sklearn.linear_model import LogisticRegression

# Train the Logistic Regression classifier
logistic_regression = LogisticRegression(max_iter=1000)
logistic_regression.fit(x_train_tfidf, y_train)

# Predictions
y_pred_lr = logistic_regression.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_lr_15 = accuracy_score(y_test, y_pred_lr)
precision_lr_15 = precision_score(y_test, y_pred_lr, average='weighted')
recall_lr_15 = recall_score(y_test, y_pred_lr, average='weighted')
f1_lr_15 = f1_score(y_test, y_pred_lr, average='weighted')
conf_matrix_lr_15 = confusion_matrix(y_test, y_pred_lr)

# Print metrics
print(f'Accuracy (Logistic Regression): {accuracy_lr_15}')
print(f'Precision (Logistic Regression): {precision_lr_15}')
print(f'Recall (Logistic Regression): {recall_lr_15}')
print(f'F1 Score (Logistic Regression): {f1_lr_15}')
print(f'Confusion Matrix (Logistic Regression):\n{conf_matrix_lr_15}')
# Out:
# (34000,) (6000,) (34000,) (6000,)
# Accuracy (Logistic Regression): 0.8915
# Precision (Logistic Regression): 0.8915642513509947
# Recall (Logistic Regression): 0.8915
# F1 Score (Logistic Regression): 0.8914904835854771
# Confusion Matrix (Logistic Regression):
# [[2636  346]
#  [ 305 2713]]

# %%
#SAME DATASET METHOD CHANGED TO KNN (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)
from sklearn.linear_model import LogisticRegression

# Train the Logistic Regression classifier
logistic_regression = LogisticRegression(max_iter=1000)
logistic_regression.fit(x_train_tfidf, y_train)

# Predictions
y_pred_lr = logistic_regression.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_lr_2 = accuracy_score(y_test, y_pred_lr)
precision_lr_2 = precision_score(y_test, y_pred_lr, average='weighted')
recall_lr_2 = recall_score(y_test, y_pred_lr, average='weighted')
f1_lr_2 = f1_score(y_test, y_pred_lr, average='weighted')
conf_matrix_lr_2 = confusion_matrix(y_test, y_pred_lr)

# Print metrics
print(f'Accuracy (Logistic Regression): {accuracy_lr_2}')
print(f'Precision (Logistic Regression): {precision_lr_2}')
print(f'Recall (Logistic Regression): {recall_lr_2}')
print(f'F1 Score (Logistic Regression): {f1_lr_2}')
print(f'Confusion Matrix (Logistic Regression):\n{conf_matrix_lr_2}')
# Out:
# (32000,) (8000,) (32000,) (8000,)
# Accuracy (Logistic Regression): 0.888875
# Precision (Logistic Regression): 0.8889261964387043
# Recall (Logistic Regression): 0.888875
# F1 Score (Logistic Regression): 0.8888644598924459
# Confusion Matrix (Logistic Regression):
# [[3496  470]
#  [ 419 3615]]

# %%
#SAME DATASET METHOD CHANGED TO KNN (CHANGES IN TEST SIZE)
import pandas as pd
import numpy as np
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

from sklearn.model_selection import train_test_split
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)


# Import necessary libraries (same preprocessing and dataset loading steps as above)

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)
from sklearn.linear_model import LogisticRegression

# Train the Logistic Regression classifier
logistic_regression = LogisticRegression(max_iter=1000)
logistic_regression.fit(x_train_tfidf, y_train)

# Predictions
y_pred_lr = logistic_regression.predict(x_test_tfidf)

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
accuracy_lr_25 = accuracy_score(y_test, y_pred_lr)
precision_lr_25 = precision_score(y_test, y_pred_lr, average='weighted')
recall_lr_25 = recall_score(y_test, y_pred_lr, average='weighted')
f1_lr_25 = f1_score(y_test, y_pred_lr, average='weighted')
conf_matrix_lr_25 = confusion_matrix(y_test, y_pred_lr)

# Print metrics
print(f'Accuracy (Logistic Regression): {accuracy_lr_25}')
print(f'Precision (Logistic Regression): {precision_lr_25}')
print(f'Recall (Logistic Regression): {recall_lr_25}')
print(f'F1 Score (Logistic Regression): {f1_lr_25}')
print(f'Confusion Matrix (Logistic Regression):\n{conf_matrix_lr_25}')
# Out:
# (30000,) (10000,) (30000,) (10000,)
# Accuracy (Logistic Regression): 0.8884
# Precision (Logistic Regression): 0.8884446989219034
# Recall (Logistic Regression): 0.8884
# F1 Score (Logistic Regression): 0.8883903557601704
# Confusion Matrix (Logistic Regression):
# [[4370  588]
#  [ 528 4514]]

# %%
# METRICS GRAPH FOR SPLIT SIZE 0.1

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of accuracy scores corresponding to each classifier (including Logistic Regression and SVM)
accuracy_scores = [accuracy_1, accuracy_dt_1, accuracy_rf_1, accuracy_knn_1, accuracy_lr_1, accuracy_svm_1]

# Create a figure with a single row and six columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, accuracy_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(accuracy_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, accuracy_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(accuracy_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(accuracy_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('Accuracy Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of precision scores corresponding to each classifier (including Logistic Regression and SVM)
precision_scores = [precision_1, precision_dt_1, precision_rf_1, precision_knn_1, precision_lr_1, precision_svm_1]

# Create a figure with a single row and three columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, precision_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('Precision')
plt.title('Precision Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(precision_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, precision_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('Precision')
plt.title('Precision Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(precision_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(precision_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('Precision Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of recall scores corresponding to each classifier (including Logistic Regression and SVM)
recall_scores = [recall_1, recall_dt_1, recall_rf_1, recall_knn_1, recall_lr_1, recall_svm_1]

# Create a figure with a single row and three columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, recall_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('Recall')
plt.title('Recall Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(recall_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, recall_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('Recall')
plt.title('Recall Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(recall_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(recall_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('Recall Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of F1 scores corresponding to each classifier (including Logistic Regression and SVM)
f1_scores = [f1_1, f1_dt_1, f1_rf_1, f1_knn_1, f1_lr_1, f1_svm_1]

# Create a figure with a single row and three columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, f1_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('F1 Score')
plt.title('F1 Score Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(f1_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, f1_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('F1 Score')
plt.title('F1 Score Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(f1_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(f1_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('F1 Score Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# List of classifier names
classifiers = ['Naive Bayes', 'Logistic Regression', 'SVM', 'Decision Tree', 'Random Forest', 'KNN']

# List of confusion matrices for each classifier
confusion_matrices = [
    conf_matrix_1,
    conf_matrix_lr_1,
    conf_matrix_svm_1,
    conf_matrix_dt_1,
    conf_matrix_rf_1,
    conf_matrix_knn_1
]

# Create a figure with a single row and six columns with a larger size (both horizontally and vertically)
plt.figure(figsize=(18, 6))

for i, (classifier, cm) in enumerate(zip(classifiers, confusion_matrices)):
    # Create a subplot for each classifier
    plt.subplot(1, 6, i + 1)
    sns.heatmap(cm, annot=True, fmt=".2f", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix ({classifier})')

# Show all plots
plt.tight_layout()
plt.show()

# %%
#METRICS GRAPH FOR SPLIT SIZE 0.15

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of accuracy scores corresponding to each classifier (including Logistic Regression and SVM)
accuracy_scores = [accuracy_15, accuracy_dt_15, accuracy_rf_15, accuracy_knn_15, accuracy_lr_15, accuracy_svm_15]

# Create a figure with a single row and six columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, accuracy_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(accuracy_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, accuracy_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(accuracy_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(accuracy_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('Accuracy Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of precision scores corresponding to each classifier (including Logistic Regression and SVM)
precision_scores = [precision_15, precision_dt_15, precision_rf_15, precision_knn_15, precision_lr_15, precision_svm_15]

# Create a figure with a single row and three columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, precision_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('Precision')
plt.title('Precision Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(precision_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, precision_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('Precision')
plt.title('Precision Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(precision_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(precision_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('Precision Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of recall scores corresponding to each classifier (including Logistic Regression and SVM)
recall_scores = [recall_15, recall_dt_15, recall_rf_15, recall_knn_15, recall_lr_15, recall_svm_15]

# Create a figure with a single row and three columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, recall_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('Recall')
plt.title('Recall Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(recall_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, recall_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('Recall')
plt.title('Recall Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(recall_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(recall_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('Recall Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of F1 scores corresponding to each classifier (including Logistic Regression and SVM)
f1_scores = [f1_1, f1_dt_1, f1_rf_1, f1_knn_1, f1_lr_1, f1_svm_1]

# Create a figure with a single row and three columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, f1_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('F1 Score')
plt.title('F1 Score Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(f1_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, f1_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('F1 Score')
plt.title('F1 Score Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(f1_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(f1_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('F1 Score Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# List of classifier names
classifiers = ['Naive Bayes', 'Logistic Regression', 'SVM', 'Decision Tree', 'Random Forest', 'KNN']

# List of confusion matrices for each classifier
confusion_matrices = [
    conf_matrix_15,
    conf_matrix_lr_15,
    conf_matrix_svm_15,
    conf_matrix_dt_15,
    conf_matrix_rf_15,
    conf_matrix_knn_15
]

# Create a figure with a single row and six columns with a larger size (both horizontally and vertically)
plt.figure(figsize=(18, 6))

for i, (classifier, cm) in enumerate(zip(classifiers, confusion_matrices)):
    # Create a subplot for each classifier
    plt.subplot(1, 6, i + 1)
    sns.heatmap(cm, annot=True, fmt=".2f", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix ({classifier})')

# Show all plots
plt.tight_layout()
plt.show()

# %%
#METRICS GRAPH FOR SPLIT SIZE 0.2

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of accuracy scores corresponding to each classifier (including Logistic Regression and SVM)
accuracy_scores = [accuracy_2, accuracy_dt_2, accuracy_rf_2, accuracy_knn_2, accuracy_lr_2, accuracy_svm_2]

# Create a figure with a single row and six columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, accuracy_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(accuracy_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, accuracy_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(accuracy_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(accuracy_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('Accuracy Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of precision scores corresponding to each classifier (including Logistic Regression and SVM)
precision_scores = [precision_2, precision_dt_2, precision_rf_2, precision_knn_2, precision_lr_2, precision_svm_2]

# Create a figure with a single row and three columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, precision_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('Precision')
plt.title('Precision Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(precision_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, precision_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('Precision')
plt.title('Precision Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(precision_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(precision_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('Precision Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of recall scores corresponding to each classifier (including Logistic Regression and SVM)
recall_scores = [recall_2, recall_dt_2, recall_rf_2, recall_knn_2, recall_lr_2, recall_svm_2]

# Create a figure with a single row and three columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, recall_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('Recall')
plt.title('Recall Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(recall_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, recall_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('Recall')
plt.title('Recall Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(recall_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(recall_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('Recall Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of F1 scores corresponding to each classifier (including Logistic Regression and SVM)
f1_scores = [f1_2, f1_dt_2, f1_rf_2, f1_knn_2, f1_lr_2, f1_svm_2]

# Create a figure with a single row and three columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, f1_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('F1 Score')
plt.title('F1 Score Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(f1_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, f1_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('F1 Score')
plt.title('F1 Score Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(f1_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(f1_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('F1 Score Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# List of classifier names
classifiers = ['Naive Bayes', 'Logistic Regression', 'SVM', 'Decision Tree', 'Random Forest', 'KNN']

# List of confusion matrices for each classifier
confusion_matrices = [
    conf_matrix_2,
    conf_matrix_lr_2,
    conf_matrix_svm_2,
    conf_matrix_dt_2,
    conf_matrix_rf_2,
    conf_matrix_knn_2
]

# Create a figure with a single row and six columns with a larger size (both horizontally and vertically)
plt.figure(figsize=(18, 6))

for i, (classifier, cm) in enumerate(zip(classifiers, confusion_matrices)):
    # Create a subplot for each classifier
    plt.subplot(1, 6, i + 1)
    sns.heatmap(cm, annot=True, fmt=".2f", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix ({classifier})')

# Show all plots
plt.tight_layout()
plt.show()

# %%
#METRICS GRAPHS FOR SPLIT SIZE 0.25

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of accuracy scores corresponding to each classifier (including Logistic Regression and SVM)
accuracy_scores = [accuracy_25, accuracy_dt_25, accuracy_rf_25, accuracy_knn_25, accuracy_lr_25, accuracy_svm_25]

# Create a figure with a single row and six columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, accuracy_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(accuracy_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, accuracy_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(accuracy_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(accuracy_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('Accuracy Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of precision scores corresponding to each classifier (including Logistic Regression and SVM)
precision_scores = [precision_25, precision_dt_25, precision_rf_25, precision_knn_25, precision_lr_25, precision_svm_25]

# Create a figure with a single row and three columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, precision_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('Precision')
plt.title('Precision Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(precision_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, precision_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('Precision')
plt.title('Precision Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(precision_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(precision_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('Precision Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of recall scores corresponding to each classifier (including Logistic Regression and SVM)
recall_scores = [recall_25, recall_dt_25, recall_rf_25, recall_knn_25, recall_lr_25, recall_svm_25]

# Create a figure with a single row and three columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, recall_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('Recall')
plt.title('Recall Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(recall_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, recall_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('Recall')
plt.title('Recall Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(recall_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(recall_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('Recall Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# List of classifier names (including Logistic Regression and SVM)
classifiers = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'KNN', 'Logistic Regression', 'SVM']

# List of F1 scores corresponding to each classifier (including Logistic Regression and SVM)
f1_scores = [f1_25, f1_dt_25, f1_rf_25, f1_knn_25, f1_lr_25, f1_svm_25]

# Create a figure with a single row and three columns with larger size (both horizontally and vertically)
plt.figure(figsize=(12, 12))

# Bar chart
plt.subplot(3, 1, 1)
plt.bar(classifiers, f1_scores, color='skyblue')
plt.xlabel('Classifiers')
plt.ylabel('F1 Score')
plt.title('F1 Score Comparison (Bar Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(f1_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Line chart
plt.subplot(3, 1, 2)
plt.plot(classifiers, f1_scores, marker='o', color='skyblue', linestyle='-', markersize=8)
plt.xlabel('Classifiers')
plt.ylabel('F1 Score')
plt.title('F1 Score Comparison (Line Chart)')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for i, v in enumerate(f1_scores):
    plt.text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom')  # Format to 3 decimal places

# Pie chart
plt.subplot(3, 1, 3)
plt.pie(f1_scores, labels=classifiers, autopct='%1.3f%%', colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink', 'lightcyan'])
plt.title('F1 Score Comparison (Pie Chart)')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# List of classifier names
classifiers = ['Naive Bayes', 'Logistic Regression', 'SVM', 'Decision Tree', 'Random Forest', 'KNN']

# List of confusion matrices for each classifier
confusion_matrices = [
    conf_matrix_25,
    conf_matrix_lr_25,
    conf_matrix_svm_25,
    conf_matrix_dt_25,
    conf_matrix_rf_25,
    conf_matrix_knn_25
]

# Create a figure with a single row and six columns with a larger size (both horizontally and vertically)
plt.figure(figsize=(18, 6))

for i, (classifier, cm) in enumerate(zip(classifiers, confusion_matrices)):
    # Create a subplot for each classifier
    plt.subplot(1, 6, i + 1)
    sns.heatmap(cm, annot=True, fmt=".2f", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix ({classifier})')

# Show all plots
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score, 
                             confusion_matrix, roc_auc_score, classification_report, log_loss)

# Download NLTK stopwords and WordNetLemmatizer
nltk.download('stopwords')
nltk.download('wordnet')

# Initialize lemmatizer and stopwords
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Text preprocessing function
def preprocess_text(text):
    # Lowercase the text
    text = text.lower()
    
    # Remove special characters, numbers, and punctuations
    text = re.sub(r'[^a-z\s]', '', text)
    
    # Tokenize and remove stopwords, and apply lemmatization
    words = text.split()
    clean_words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    
    return ' '.join(clean_words)

# Load the dataset
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

# Apply preprocessing
data['cleaned_text'] = data['text'].apply(preprocess_text)

# Split the data
X = data['cleaned_text']
y = data['label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer(max_features=5000)
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# Train Naive Bayes Classifier
naive_bayes = MultinomialNB()
naive_bayes.fit(X_train_tfidf, y_train)

# Predictions
y_pred = naive_bayes.predict(X_test_tfidf)
y_pred_prob = naive_bayes.predict_proba(X_test_tfidf)

# Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
#conf_matrix = confusion_matrix(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_prob[:, 1])
log_loss_value = log_loss(y_test, y_pred_prob)

# Print metrics
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
#print(f'Confusion Matrix:\n{conf_matrix}')
print(f'AUC-ROC Score: {roc_auc}')
print(f'Log Loss: {log_loss_value}')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/manavpathak/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/manavpathak/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Accuracy: 0.848
# Precision: 0.848003824137669
# Recall: 0.848
# F1 Score: 0.8480010640521386
# AUC-ROC Score: 0.9243701596902202
# Log Loss: 0.417771095803104

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, log_loss, matthews_corrcoef, classification_report, roc_curve, auc
from sklearn.pipeline import Pipeline
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import matplotlib.pyplot as plt

# Load the dataset
file_name = "/Users/manavpathak/Documents/Idmb sentiment data/Train.csv"
data = pd.read_csv(file_name)

# Better text preprocessing
nltk.download('stopwords')
nltk.download('wordnet')
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    # Lowercasing and removing special characters
    text = text.lower()
    text = re.sub(r'\W', ' ', text)
    # Remove stopwords and apply lemmatization
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Apply preprocessing
data['text'] = data['text'].apply(preprocess_text)

# Split the data
x = data['text']
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# TF-IDF Vectorization with optimization (max_features increased)
tfidf_vectorizer = TfidfVectorizer(max_features=10000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

# KNN Classifier with Hyperparameter Tuning using GridSearchCV
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(max_features=10000)),
    ('knn', KNeighborsClassifier())
])

# Parameter grid for hyperparameter tuning
param_grid = {
    'knn__n_neighbors': [3, 5, 7, 9],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['euclidean', 'manhattan', 'cosine']
}

# GridSearchCV to find the best parameters
grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(x_train, y_train)

# Best model after tuning
best_model = grid_search.best_estimator_
y_pred_knn = best_model.predict(x_test)
y_prob_knn = best_model.predict_proba(x_test)  # For Log Loss and ROC AUC

# Metrics
accuracy_knn_optimized = accuracy_score(y_test, y_pred_knn)
precision_knn_optimized = precision_score(y_test, y_pred_knn, average='weighted')
recall_knn_optimized = recall_score(y_test, y_pred_knn, average='weighted')
f1_knn_optimized = f1_score(y_test, y_pred_knn, average='weighted')
conf_matrix_knn_optimized = confusion_matrix(y_test, y_pred_knn)

# Additional Metrics
log_loss_knn = log_loss(y_test, y_prob_knn)
mcc_knn = matthews_corrcoef(y_test, y_pred_knn)
roc_auc_knn = roc_auc_score(y_test, y_prob_knn, multi_class='ovr')

# Print basic metrics
print(f'Best Parameters: {grid_search.best_params_}')
print(f'Accuracy (Optimized KNN): {accuracy_knn_optimized}')
print(f'Precision (Optimized KNN): {precision_knn_optimized}')
print(f'Recall (Optimized KNN): {recall_knn_optimized}')
print(f'F1 Score (Optimized KNN): {f1_knn_optimized}')
print(f'Confusion Matrix (Optimized KNN):\n{conf_matrix_knn_optimized}')

# Print additional metrics
print(f'Log Loss (Optimized KNN): {log_loss_knn}')
print(f'Matthews Correlation Coefficient (Optimized KNN): {mcc_knn}')
print(f'ROC AUC Score (Optimized KNN): {roc_auc_knn}')

# Classification Report
print(f'Classification Report:\n{classification_report(y_test, y_pred_knn)}')

# Plotting ROC curve
fpr = {}
tpr = {}
roc_auc = {}

for i in range(len(np.unique(y_test))):
    fpr[i], tpr[i], _ = roc_curve(y_test, y_prob_knn[:, i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot each class's ROC curve
plt.figure(figsize=(8, 6))
for i in range(len(fpr)):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} ROC curve (area = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Each Class')
plt.legend(loc='lower right')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/manavpathak/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/manavpathak/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 61
#      59 # GridSearchCV to find the best parameters
#      60 grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
# ---> 61 grid_search.fit(x_train, y_train)
#      63 # Best model after tuning
#      64 best_model = grid_search.best_estimator_
#
# File ~/Documents/research_paper/.venv/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
# ...
